# %%
# !pip install requests beautifulsoup4 python-docx tldextract urllib3

# %%
import re, time, urllib.parse as up
from collections import deque, defaultdict
import requests
from bs4 import BeautifulSoup
from urllib.robotparser import RobotFileParser
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import tldextract

# %%
SITES = [
    # Seed URLs (static forums / blogs). Add/remove as you like.
    "https://www.clearadmit.com/",
    "https://gmatclub.com/forum/",
    "https://find-mba.com/board/general-forum",
]

# %%
KEYWORDS = [
    # Exact phrases/keywords to match (case-insensitive).
    # Add/remove freely.
    "Duke Fuqua",
    "Fuqua MBA", "Duke MBA",
    "Fuqua MMS", "Duke MMS",
    "Fuqua MQM", "Duke MQM",
    "Fuqua MSQM", "Duke MSQM",
    "Duke Business Analytics", "Duke MSBA",
    "Fuqua EMBA", "Fuqua GEMBA", "Fuqua WEMBA",
]

# %%
DEGREE_TOKENS = [
    r"MSBA", r"MBA", r"M\.B\.A", r"EMBA", r"GEMBA", r"WEMBA",
    r"MMS(?:\:FOB|:DKU)?", r"MQM(?:\:BA)?", r"MSQM(?:\:HA)?"
]

# %%
USER_AGENT = "Mozilla/5.0 (compatible; FuquaStaticScanner/1.0; +https://fuqua.duke.edu)"
DEFAULT_TIMEOUT = 15
REQUEST_DELAY_SEC = 1.5     # polite delay between requests
MAX_PAGES_PER_DOMAIN = 40   # cap pages per seed domain
MAX_DEPTH = 2               # BFS crawl depth
ALLOWED_CONTENT_TYPES = ("text/html", "application/xhtml+xml")

# %%
STATIC_ALLOWLIST = {"clearadmit.com", "gmatclub.com", "find-mba.com"}
EXCLUDE_DOMAINS = {
    "reddit.com", "twitter.com", "x.com", "quora.com",
    "chasedream.com", # JS-heavy (skip in Week 3)
    "feedspot.com",
}

# %%
def new_session():
    s = requests.Session()
    s.headers.update({"User-Agent": USER_AGENT, "Accept": "text/html,application/xhtml+xml;q=0.9,*/*;q=0.8"})
    retry = Retry(total=3, backoff_factor=0.5,
                  status_forcelist=[429, 500, 502, 503, 504],
                  allowed_methods=["GET"])
    s.mount("http://", HTTPAdapter(max_retries=retry))
    s.mount("https://", HTTPAdapter(max_retries=retry))
    return s

# %%
def domain_of(url):
    ext = tldextract.extract(url)
    return ".".join(p for p in [ext.domain, ext.suffix] if p)

# %%
def is_static_domain(url):
    dom = domain_of(url)
    if dom in EXCLUDE_DOMAINS:
        return False
    if dom in STATIC_ALLOWLIST:
        return True
    # Heuristic: allow if not in common JS-heavy/excluded list
    return True

# %%
def same_reg_domain(u1, u2):
    a, b = tldextract.extract(u1), tldextract.extract(u2)
    return (a.domain, a.suffix) == (b.domain, b.suffix)

# %%
def canonicalize_url(base, link):
    try:
        url = up.urljoin(base, link)
        parsed = up.urlparse(url)
        if parsed.scheme not in ("http", "https"):
            return None
        # drop fragments
        return up.urlunparse(parsed._replace(fragment=""))
    except:
        return None

# %%
def allowed_by_robots(url, session, cache):
    parsed = up.urlparse(url)
    root = f"{parsed.scheme}://{parsed.netloc}"
    if root not in cache:
        rp = RobotFileParser()
        robots_url = up.urljoin(root, "/robots.txt")
        try:
            r = session.get(robots_url, timeout=DEFAULT_TIMEOUT)
            content = r.text if r.status_code == 200 else ""
        except Exception:
            content = ""
        rp.parse(content.splitlines())
        cache[root] = rp
    return cache[root].can_fetch(USER_AGENT, url)

# %%
def fetch(url, session):
    resp = session.get(url, timeout=DEFAULT_TIMEOUT)
    ctype = resp.headers.get("Content-Type", "").lower()
    if not any(ct in ctype for ct in ALLOWED_CONTENT_TYPES):
        raise ValueError("Non-HTML content")
    return resp

# %%
def extract_meta(soup):
    title = (soup.title.string or "").strip() if soup.title else ""
    # common timestamp hints
    ts = None
    for sel in [
        "meta[property='article:published_time']",
        "meta[name='pubdate']",
        "meta[itemprop='datePublished']",
        "time[datetime]"
    ]:
        m = soup.select_one(sel)
        if m:
            ts = (m.get("content") or m.get("datetime") or "").strip()
            if ts:
                break
    # author hints
    author = None
    for sel in [
        "meta[name='author']","a[rel='author']",
        ".author a",".author",".byline a",".byline","[itemprop='author']"
    ]:
        m = soup.select_one(sel)
        if m:
            author = (m.get("content") or m.get_text()).strip()
            if author:
                break
    return title[:300], (ts or "")[:100], (author or "")[:120]

# %%
def visible_text(soup):
    for s in soup(["script","style","noscript","iframe","svg"]):
        s.decompose()
    return soup.get_text(separator=" ", strip=True)

# %%
def build_patterns(phrases):
    exact = [re.compile(re.escape(p), re.IGNORECASE) for p in phrases if p.strip()]
    prox_duke_fuqua = re.compile(r"\bDuke\b(?:\W+\w+){0,10}?\W+\bFuqua\b|\bFuqua\b(?:\W+\w+){0,10}?\W+\bDuke\b", re.IGNORECASE)
    deg_union = "(?:" + "|".join(DEGREE_TOKENS) + ")"
    prox_degree = re.compile(
        rf"(?:\bDuke\b|\bFuqua\b)(?:\W+\w+){{0,5}}?\W+\b{deg_union}\b|\b{deg_union}\b(?:\W+\w+){{0,5}}?\W+(?:\bDuke\b|\bFuqua\b)",
        re.IGNORECASE
    )
    return exact, [prox_duke_fuqua, prox_degree]

# %%
def find_snippet(text, span, radius=90):
    s, e = span
    s = max(0, s - radius); e = min(len(text), e + radius)
    snip = text[s:e]
    return re.sub(r"\s+", " ", snip).strip()

# %%
def scan_text(text, exact_patterns, prox_patterns):
    hits = []
    for pat in exact_patterns:
        for m in pat.finditer(text):
            hits.append(("exact", m.span()))
    for pat in prox_patterns:
        for m in pat.finditer(text):
            hits.append(("prox", m.span()))
    hits.sort(key=lambda x: x[1][0])
    return hits

# %%
def crawl_domain(seed_url, phrases):
    if not is_static_domain(seed_url):
        return []

    session = new_session()
    robots_cache = {}
    visited = set()
    per_domain_count = 0
    results = []
    q = deque([(seed_url, 0)])

    origin = up.urlparse(seed_url).scheme + "://" + up.urlparse(seed_url).netloc
    exact_patterns, prox_patterns = build_patterns(phrases)

    while q and per_domain_count < MAX_PAGES_PER_DOMAIN:
        url, depth = q.popleft()
        if url in visited or depth > MAX_DEPTH:
            continue
        visited.add(url)
        if not same_reg_domain(seed_url, url):
            continue
        if not allowed_by_robots(url, session, robots_cache):
            continue

        try:
            resp = fetch(url, session)
            time.sleep(REQUEST_DELAY_SEC)
        except Exception:
            continue

        per_domain_count += 1
        soup = BeautifulSoup(resp.text, "html.parser")
        title, ts, author = extract_meta(soup)
        text = visible_text(soup)

        matches = scan_text(text, exact_patterns, prox_patterns)
        if matches:
            mtype, mspan = matches[0]
            snippet = find_snippet(text, mspan)
            results.append({
                "title": title or "(no title)",
                "url": url,
                "timestamp": ts,
                "author": author,
                "match_type": mtype,
                "snippet": snippet
            })

        # enqueue internal links
        for a in soup.find_all("a", href=True):
            nxt = canonicalize_url(url, a["href"])
            if not nxt:
                continue
            if not nxt.startswith(origin):
                continue
            if nxt in visited:
                continue
            low = nxt.lower()
            if any(x in low for x in ["/login","/signup","/register","/rss","/feed","/wp-json"]):
                continue
            q.append((nxt, depth + 1))

    return results

# %%
def run_all(sites=SITES, phrases=KEYWORDS):
    grouped = defaultdict(list)
    for seed in sites:
        if not seed.startswith(("http://","https://")):
            continue
        dom = domain_of(seed)
        if dom in EXCLUDE_DOMAINS:
            print(f"- Skipping excluded: {seed}")
            continue
        rows = crawl_domain(seed, phrases)
        grouped[dom].extend(rows)

    # Print results
    any_hits = False
    for dom, rows in grouped.items():
        if not rows:
            print(f"[{dom}] No matches found.")
            continue
        any_hits = True
        print(f"\n=== {dom} — {len(rows)} match(es) ===")
        for i, r in enumerate(rows, 1):
            print(f"\n[{i}] {r['title']}")
            print(f"URL: {r['url']}")
            if r["timestamp"]:
                print(f"Time: {r['timestamp']}")
            if r["author"]:
                print(f"Author: {r['author']}")
            print(f"Match: {r['match_type']}")
            print(f"Snippet: {r['snippet']}")
    if not any_hits:
        print("No matches across all seeds.")

# %%
run_all()
# Out:
# === clearadmit.com — 31 match(es) ===
#
# [1] Clear Admit: MBA News, Admissions Advice & Trends
# URL: https://www.clearadmit.com/
# Match: exact
# Snippet: xon Weekly Columns Fridays from the Frontline: Leading With Curiosity in the Age of AI at Duke Fuqua Myth Busters MBA Mythbusters: All MBA Roads Lead to Consulting, Tech or Investment Bankin
#
# [2] Clear Admit: MBA News, Admissions Advice & Trends
# URL: https://www.clearadmit.com
# Match: exact
# Snippet: xon Weekly Columns Fridays from the Frontline: Leading With Curiosity in the Age of AI at Duke Fuqua Myth Busters MBA Mythbusters: All MBA Roads Lead to Consulting, Tech or Investment Bankin
#
# [3] Live MBA Admissions Decisions | MBA Livewire | Clear Admit
# URL: https://www.clearadmit.com/livewire/
# Match: prox
# Snippet: bridge / Judge Carnegie Mellon / Tepper CEIBS Columbia Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Edinburgh emlyon Emory / Goizueta ESADE ESCP ESMT Berlin Florida / Warrington Georgetown
#
# [4] Data Dashboard | Clear Admit
# URL: https://www.clearadmit.com/livewire-data-dashboard/
# Match: prox
# Snippet: ll Cambridge / Judge Carnegie Mellon / Tepper Columbia Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Emory / Goizueta Georgetown / McDonough Harvard Business School IESE Indiana / Kelley INS
#
# [5] Events Archives | Clear Admit
# URL: https://www.clearadmit.com/category/news/events/
# Match: exact
# Snippet: dents and recent alumni of some of the top MBA programs such as Columbia Business School, Duke Fuqua, and others. Don’t miss this opportunity to hear from Real Humans and gain valuable advic
#
# [6] MBA Admissions Podcast | Clear Admit
# URL: https://www.clearadmit.com/category/advice/mba-podcast/
# Match: exact
# Snippet: missions interview. We also took a look at recommendations. Panelists from Berkeley Haas, Duke Fuqua, HBS, Indiana Kelley Our expert panel includes Eric Askins, Executive Director of Admissi
#
# [7] My Account | Clear Admit
# URL: https://www.clearadmit.com/my-account/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [8] MBA Admissions and Career Advice | Clear Admit
# URL: https://www.clearadmit.com/mba-admissions/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [9] MBA Admissions Tips | Clear Admit MBA Admissions Tips
# URL: https://www.clearadmit.com/mba-admissions-tips/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [10] MBA Application Deadlines 2025-2026 | Clear Admit
# URL: https://www.clearadmit.com/mba-application-deadlines/
# Match: prox
# Snippet: pper CEIBS U. Chicago / Booth Columbia Business School Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Emory / Goizueta Georgetown / McDonough Georgia Tech Scheller Georgia Terry Harvard Busin
#
# [11] MBA Admissions: Essay Topic Analyses 2025-2026 | Clear Admit
# URL: https://www.clearadmit.com/mba-admissions-essay-topics-analyses/
# Match: prox
# Snippet: n / Tepper U. Chicago / Booth Columbia Business School Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Georgia Tech Scheller Harvard Business School Indian School of Business INSEAD London Bus
#
# [12] MBA Recommendation Questions 2025-2026 | Clear Admit
# URL: https://www.clearadmit.com/mba-admissions-recommendation-questions/
# Match: prox
# Snippet: / Haas Boston College / Carroll CEIBS Chicago / Booth CMU Tepper Columbia Business School Duke / Fuqua ESCP ESMT Berlin Florida Warrington Georgetown / McDonough Georgia Tech Scheller Georgia
#
# [13] MBA News | Clear Admit
# URL: https://www.clearadmit.com/blog/
# Match: prox
# Snippet: Additional Round 4 Deadline MBA Admissions Deadlines Michigan Ross Adds Round 4 Deadline MBA Admissions Deadlines Duke Fuqua Announces 2022-2023 MBA Admissions Deadline Changes MBA Admissions Deadlines Round
#
# [14] Admissions Director Q&A Archives | Clear Admit
# URL: https://www.clearadmit.com/category/admissions-director-qa/
# Match: exact
# Snippet: uate program’s Read more Published: July 2, 2025 Admissions Director Q&A: Shari Hubert of Duke Fuqua In this Admissions Director Q&A, we welcome back Associate Dean of Admissions at Duke Uni
#
# [15] Class Profile Archives | Clear Admit
# URL: https://www.clearadmit.com/category/news/mba-news/class-profile/
# Match: exact
# Snippet: uly global and diverse community, with international Read more Published: August 25, 2024 Duke Fuqua MBA Class Profile: Daytime MBA Class of 2026 Achieves Gender Parity Duke University’s Fuq
#
# [16] Real Humans of MBA Students Archives | Clear Admit
# URL: https://www.clearadmit.com/category/real-humans-of-mba-students/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [17] Real Humans: Alumni | Clear Admit
# URL: https://www.clearadmit.com/real-humans-alumni/
# Match: exact
# Snippet: Cathy Chen, Chicago Booth MBA ’20, Strategy Manager Real Humans of Accenture: Dan Nolan, Duke Fuqua MBA ’22, Senior Strategy Consultant Real Humans of Accenture: James Morris, Indiana Kelle
#
# [18] Fridays from the Frontline Archives | Clear Admit
# URL: https://www.clearadmit.com/category/weekly-columns/fridays-from-the-frontline/
# Match: exact
# Snippet: hed: July 17, 2025 Fridays from the Frontline: Leading With Curiosity in the Age of AI at Duke Fuqua In this Fridays from the Frontline, Duke Fuqua Daytime MBA candidate, Shriya Boppana, sha
#
# [19] Introduction to Clear Admit's MBA Career Trends Series | Clear Admit
# URL: https://www.clearadmit.com/introduction-to-top-mba-career-placement-outcomes-series/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [20] MBA School Profiles & Resources | Clear Admit
# URL: https://www.clearadmit.com/school/
# Match: prox
# Snippet: MEAN GMAT: 727 MEAN GPA: 3.6 Livewire Decisionwire Interview Reports Essay Topic Analysis MBA Admissions Deadlines View Full Profile Duke / Fuqua CLASS SIZE: 427 Women: 51% 80% GMAT RANGE: 660 - 760 80% GPA Range: 3.17 - 3.89 L
#
# [21] Masters in Management Programs | Clear Admit
# URL: https://www.clearadmit.com/programs/masters-in-management/
# Match: exact
# Snippet: f Science in Management (MSM) View Program Cornell Johnson MPS in Management View Program Duke Fuqua Master of Management Studies (MMS) View Program Georgetown McDonough MS In Management (Mi
#
# [22] Best Business Schools & MBA Rankings | Clear Admit
# URL: https://www.clearadmit.com/best-business-schools/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [23] MBA Rankings | Clear Admit
# URL: https://www.clearadmit.com/mba-rankings/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [24] Top Deferred MBA Programs 2025 Guide
# URL: https://www.clearadmit.com/mba-admissions-tips/top-deferred-enrollment-mba-programs/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [25] Top Masters in Management Programs in the U.S. | Clear Admit
# URL: https://www.clearadmit.com/top-masters-in-management-programs-in-the-u-s/
# Match: exact
# Snippet: betical order: Chicago Booth Master in Management (MiM) Cornell Johnson MPS in Management Duke Fuqua Master of Management Studies (MMS) Emory Goizueta Master in Management (MiM) Georgetown M
#
# [26] MBA Programs that Don’t Require GMAT, GRE or EA Test Scores | Clear Admit
# URL: https://www.clearadmit.com/mba-programs-that-dont-require-gmat-gre-or-ea-test-scores/
# Match: exact
# Snippet: test scores. Test waivers are available based on academic and professional requirements. Duke Fuqua Duke University Fuqua School of Business does require Full-Time Daytime MBA applicants an
#
# [27] Real Numbers of MBA Admissions | Clear Admit
# URL: https://www.clearadmit.com/real-numbers-of-mba-admissions/
# Match: prox
# Snippet: es in the United States. 12 August 8, 2025 11:01am ET Applying: Carnegie Mellon / Tepper, Duke / Fuqua, Emory / Goizueta, Georgetown / McDonough, Michigan / Ross, Rice / Jones, Temple / Fox, U
#
# [28] MBA Admissions Interview Reports Archive | Clear Admit
# URL: https://www.clearadmit.com/interview-reports/
# Match: prox
# Snippet: bridge / Judge Carnegie Mellon / Tepper CEIBS Columbia Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Emory / Goizueta ESADE ESMT Berlin Georgetown / McDonough Georgia / Terry Georgia Tech /
#
# [29] MBA Interview Tips & Resources | Clear Admit
# URL: https://www.clearadmit.com/advice/interviews/
# Time: PT0H23M16S
# Match: exact
# Snippet: when you’ve finished interviewing 😊 Harvard Business School Interview Reports Click Here Duke Fuqua Interview Reports Click Here Dartmouth Tuck Interview Reports Click Here Clear Admit Inte
#
# [30] MBA DecisionWire | Clear Admit
# URL: https://www.clearadmit.com/decisionwire/
# Match: prox
# Snippet: IBS U. Chicago Booth Carnegie Mellon / Tepper Columbia Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Edinburgh emlyon Emory / Goizueta ESADE ESCP ESMT Berlin Florida / Warrington Georgetown
#
# [31] MBA Profile Review | MBA ApplyWire | Clear Admit
# URL: https://www.clearadmit.com/applywire/
# Match: prox
# Snippet: bridge / Judge Carnegie Mellon / Tepper CEIBS Columbia Cornell / Johnson Dartmouth / Tuck Duke / Fuqua Edinburgh emlyon Emory / Goizueta ESADE ESCP ESMT Berlin Florida / Warrington George Wash
# [gmatclub.com] No matches found.
#
# === find-mba.com — 3 match(es) ===
#
# [1] MBA Programs in Energy and Natural Resources 2025
#           | FIND MBA
# URL: https://find-mba.com/specializations/energy-and-natural-resources
# Match: prox
# Snippet: / JD (The Francis J. & WM. Polk Carey Program), MBA / DMD (Doctor of Medicine in... more… Duke University Fuqua School of Business Durham, North Carolina 52 Followers 105 Discussions Full-Time: Daytime
#
# [2] Articles
#           | FIND MBA
# URL: https://find-mba.com/articles
# Match: prox
# Snippet: ready busy schedule can create stress but there are tools to get you through the process. MBA student Nicolas Kudrna at Duke shares what has helped him stay on top of things, from booking appointments to organizing
#
# [3] MBA Rankings
#           | FIND MBA
# URL: https://find-mba.com/mba-rankings
# Match: prox
# Snippet: nology Massachusetts 10 Kellogg School of Management, Northwestern University Illinois 11 Duke University Fuqua School of Business North Carolina 13 Harvard Business School (HBS) Massachusetts 13 Corne
